# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from typing import Tuple, Optional
import numpy as np

class LidDrivenCavityPINN:
    def __init__(self, config: Optional[dict] = None):
        """
        Initialize the lid-driven cavity PINN solver with configuration.
        
        Args:
            config: Dictionary containing configuration parameters. If None, defaults will be used.
        """
        # Set default configuration
        self.default_config = {
            'domain': {
                'x_min': 0.0,
                'x_max': 1.0,
                'y_min': 0.0,
                'y_max': 1.0
            },
            'physics': {
                'U_lid': 1.0,
                'nu': 0.025  # kinematic viscosity
            },
            'training': {
                'N_f': 5000,  # Number of collocation points
                'N_b': 500,   # Number of boundary points
                'target_loss': 0.003,
                'max_epochs': 50000,
                'learning_rate': 1e-3
            },
            'model': {
                'num_shared_layers': 5,
                'num_head_layers': 2,
                'num_neurons': 40,
                'activation': 'tanh'
            }
        }
        
        # Update with user-provided config
        self.config = {**self.default_config, **(config or {})}
        
        # Initialize model and data
        self.model = self._build_model()
        self.optimizer = tf.keras.optimizers.Adam(
            learning_rate=self.config['training']['learning_rate']
        )
        self._generate_data()

        # Initialize loss tracking
        self.loss_history = {
                'total_loss': [],
                'pde_loss': [],
                'bc_loss': [],
                'epoch_times': []
            }
        self.start_time = None
        
    def _build_model(self) -> tf.keras.Model:
        """Build the enhanced PINN model architecture."""
        num_shared = self.config['model']['num_shared_layers']
        num_head = self.config['model']['num_head_layers']
        num_neurons = self.config['model']['num_neurons']
        activation = self.config['model']['activation']
        
        inputs = tf.keras.Input(shape=(2,))
        x, y = inputs[:, 0:1], inputs[:, 1:2]
        
        # Feature expansion
        X = tf.concat([inputs, tf.sin(inputs), tf.cos(inputs)], axis=1)
        
        # Shared layers
        for _ in range(num_shared):
            X = tf.keras.layers.Dense(
                num_neurons, 
                activation=activation, 
                kernel_initializer='glorot_normal'
            )(X)
        
        # Separate heads
        def build_head(X):
            for _ in range(num_head):
                X = tf.keras.layers.Dense(
                    num_neurons, 
                    activation=activation, 
                    kernel_initializer='glorot_normal'
                )(X)
            return X
        
        # u head
        uX = build_head(X)
        u = tf.keras.layers.Dense(1, activation=None)(uX)
        
        # v head
        vX = build_head(X)
        v = tf.keras.layers.Dense(1, activation=None)(vX)
        
        # p head
        pX = build_head(X)
        p = tf.keras.layers.Dense(1, activation=None)(pX)
        
        return tf.keras.Model(inputs=inputs, outputs=[u, v, p])
    
    def _generate_data(self) -> None:
        """Generate collocation and boundary points."""
        cfg = self.config
        N_f = cfg['training']['N_f']
        N_b = cfg['training']['N_b']
        
        # Collocation points
        x_f = tf.random.uniform((N_f, 1), cfg['domain']['x_min'], cfg['domain']['x_max'], dtype=tf.float32)
        y_f = tf.random.uniform((N_f, 1), cfg['domain']['y_min'], cfg['domain']['y_max'], dtype=tf.float32)
        self.X_f = tf.concat([x_f, y_f], axis=1)
        
        # Boundary points (split equally among 4 boundaries)
        N_b_per_edge = N_b // 4
        
        # Left boundary
        x_left = cfg['domain']['x_min'] * tf.ones((N_b_per_edge, 1), dtype=tf.float32)
        y_left = tf.random.uniform((N_b_per_edge, 1), cfg['domain']['y_min'], cfg['domain']['y_max'], dtype=tf.float32)
        
        # Right boundary
        x_right = cfg['domain']['x_max'] * tf.ones((N_b_per_edge, 1), dtype=tf.float32)
        y_right = tf.random.uniform((N_b_per_edge, 1), cfg['domain']['y_min'], cfg['domain']['y_max'], dtype=tf.float32)
        
        # Bottom boundary
        x_bottom = tf.random.uniform((N_b_per_edge, 1), cfg['domain']['x_min'], cfg['domain']['x_max'], dtype=tf.float32)
        y_bottom = cfg['domain']['y_min'] * tf.ones((N_b_per_edge, 1), dtype=tf.float32)
        
        # Top boundary
        x_top = tf.random.uniform((N_b_per_edge, 1), cfg['domain']['x_min'], cfg['domain']['x_max'], dtype=tf.float32)
        y_top = cfg['domain']['y_max'] * tf.ones((N_b_per_edge, 1), dtype=tf.float32)
        
        self.X_b = tf.concat([
            tf.concat([x_left, y_left], axis=1),
            tf.concat([x_right, y_right], axis=1),
            tf.concat([x_bottom, y_bottom], axis=1),
            tf.concat([x_top, y_top], axis=1)
        ], axis=0)
        
        # Boundary conditions
        U_lid = cfg['physics']['U_lid']
        self.u_b = tf.concat([
            tf.zeros((3 * N_b_per_edge, 1), dtype=tf.float32),  # u=0 on side and bottom
            U_lid * tf.ones((N_b_per_edge, 1), dtype=tf.float32)  # u=U_lid on top
        ], axis=0)
        
        self.v_b = tf.zeros((N_b, 1), dtype=tf.float32)  # v=0 everywhere on boundary
    
    def _compute_losses(self, X_f: tf.Tensor, X_b: tf.Tensor, u_b: tf.Tensor, v_b: tf.Tensor) -> Tuple[tf.Tensor, tf.Tensor, tf.Tensor]:
        """Compute PDE and boundary condition losses."""
        with tf.GradientTape(persistent=True) as tape:
            tape.watch(X_f)
            u, v, p = self.model(X_f)
            u = tf.squeeze(u)
            v = tf.squeeze(v)
            p = tf.squeeze(p)

            # First derivatives
            u_x = tape.gradient(u, X_f)[:, 0]
            u_y = tape.gradient(u, X_f)[:, 1]
            v_x = tape.gradient(v, X_f)[:, 0]
            v_y = tape.gradient(v, X_f)[:, 1]

            continuity = u_x + v_y

            # Second derivatives
            with tf.GradientTape(persistent=True) as tape2:
                tape2.watch(X_f)
                u, v, p = self.model(X_f)
                u = tf.squeeze(u)
                v = tf.squeeze(v)
                p = tf.squeeze(p)

                u_x = tape.gradient(u, X_f)[:, 0]
                u_y = tape.gradient(u, X_f)[:, 1]
                v_x = tape.gradient(v, X_f)[:, 0]
                v_y = tape.gradient(v, X_f)[:, 1]

            u_xx = tape2.gradient(u_x, X_f)[:, 0]
            u_yy = tape2.gradient(u_y, X_f)[:, 1]
            v_xx = tape2.gradient(v_x, X_f)[:, 0]
            v_yy = tape2.gradient(v_y, X_f)[:, 1]

            # Pressure gradients
            p_x = tape.gradient(p, X_f)[:, 0]
            p_y = tape.gradient(p, X_f)[:, 1]

            # Momentum equations
            momentum_u = u * u_x + v * u_y + p_x - self.config['physics']['nu'] * (u_xx + u_yy)
            momentum_v = u * v_x + v * v_y + p_y - self.config['physics']['nu'] * (v_xx + v_yy)

            # PDE loss
            f_pde = tf.reduce_mean(tf.square(continuity)) + \
                    tf.reduce_mean(tf.square(momentum_u)) + \
                    tf.reduce_mean(tf.square(momentum_v))

        # Boundary condition loss
        u_pred_b, v_pred_b, _ = self.model(X_b)
        bc_loss = tf.reduce_mean(tf.square(u_pred_b - u_b)) + \
                  tf.reduce_mean(tf.square(v_pred_b - v_b))

        total_loss = f_pde + bc_loss
        # total_loss = f_pde + tf.maximum(2.4 * bc_loss, 0.008)
        return total_loss, f_pde, bc_loss
    
    @tf.function
    def _train_step(self) -> Tuple[tf.Tensor, tf.Tensor, tf.Tensor]:
        """Single training step."""
        with tf.GradientTape() as tape:
            total_loss, pde_loss, bc_loss = self._compute_losses(
                self.X_f, self.X_b, self.u_b, self.v_b
            )
        grads = tape.gradient(total_loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return total_loss, pde_loss, bc_loss
    
    def train(self) -> None:
        """Train the model until target loss or max epochs is reached."""
        target_loss = self.config['training']['target_loss']
        max_epochs = self.config['training']['max_epochs']
        
        self.start_time = tf.timestamp()
        
        for epoch in range(max_epochs):
            total_loss, pde_loss, bc_loss = self._train_step()
            
            # Store losses
            self.loss_history['total_loss'].append(total_loss.numpy())
            self.loss_history['pde_loss'].append(pde_loss.numpy())
            self.loss_history['bc_loss'].append(bc_loss.numpy())
            self.loss_history['epoch_times'].append(tf.timestamp().numpy() - self.start_time.numpy())
            
            if epoch % 100 == 0:
                print(f"Epoch {epoch}: Total Loss = {total_loss.numpy():.4e}, "
                      f"PDE Loss = {pde_loss.numpy():.4e}, BC Loss = {bc_loss.numpy():.4e}")
            
            if total_loss <= target_loss:
                print(f"Training converged at epoch {epoch} with loss {total_loss.numpy():.4e}")
                break
        
        if epoch == max_epochs - 1:
            print(f"Reached maximum epochs ({max_epochs}) with final loss {total_loss.numpy():.4e}")

    
    def plot_training_points(self) -> None:
        """Visualize the collocation and boundary points."""
        X_f_np = self.X_f.numpy()
        X_b_np = self.X_b.numpy()
        
        plt.figure(figsize=(8, 8))
        plt.scatter(X_f_np[:, 0], X_f_np[:, 1], color='skyblue', s=1, 
                   label='Collocation Points', alpha=0.5)
        plt.scatter(X_b_np[:, 0], X_b_np[:, 1], color='crimson', s=10, 
                   label='Boundary Points', alpha=0.8)
        plt.xlabel('x')
        plt.ylabel('y')
        plt.title('PINN: Collocation vs Boundary Points')
        plt.legend()
        plt.grid(True)
        plt.axis('square')
        plt.show()

    

    def plot_velocity_contour(self, resolution: int = 100, dpi: int = 100) -> None:
        """
        Plot the velocity magnitude as filled contours.
        
        Args:
            resolution: Number of grid points in each direction
            dpi: Resolution of the output figure
        """
        x_plot = tf.linspace(self.config['domain']['x_min'], 
                            self.config['domain']['x_max'], 
                            resolution)
        y_plot = tf.linspace(self.config['domain']['y_min'], 
                            self.config['domain']['y_max'], 
                            resolution)
        X_grid, Y_grid = tf.meshgrid(x_plot, y_plot)
        XY = tf.stack([tf.reshape(X_grid, [-1]), tf.reshape(Y_grid, [-1])], axis=1)

        u_pred, v_pred, _ = self.model(XY)
        u_pred = tf.reshape(u_pred, (resolution, resolution)).numpy()
        v_pred = tf.reshape(v_pred, (resolution, resolution)).numpy()
        speed = np.sqrt(u_pred**2 + v_pred**2)

        fig, ax = plt.subplots(figsize=(5.5, 4), dpi=dpi)
        contour = ax.contourf(
            X_grid.numpy(), Y_grid.numpy(),
            speed,
            levels=100,
            cmap='coolwarm'
        )

        cbar = fig.colorbar(contour, ax=ax, pad=0.02)
        cbar.set_label('Velocity Magnitude', fontsize=10)

        ax.set_title('Velocity Magnitude Field', fontsize=11)
        ax.set_xlabel('x', fontsize=10)
        ax.set_ylabel('y', fontsize=10)
        ax.set_aspect('equal')
        ax.tick_params(labelsize=8)
        plt.tight_layout()
        plt.show()

    def find_vortex_center(self, wall: str = 'left', margin: float = 0.2, grid_res: int = 200) -> np.ndarray:
        """
        Find the approximate center of secondary vortex near specified wall.
        
        Args:
            wall: 'left' or 'right' wall to search near
            margin: Fraction of domain to search from wall (0-1)
            grid_res: Resolution of the search grid
        Returns:
            vortex_center (x, y) coordinates
        """
        assert wall in ['left', 'right'], "wall must be 'left' or 'right'"
        
        domain = self.config['domain']
        if wall == 'left':
            x_start, x_end = domain['x_min'], domain['x_min'] + margin * (domain['x_max'] - domain['x_min'])
        else:
            x_start, x_end = domain['x_max'] - margin * (domain['x_max'] - domain['x_min']), domain['x_max']

        y_start, y_end = domain['y_min'], domain['y_min'] + margin * (domain['y_max'] - domain['y_min'])

        x = tf.linspace(x_start, x_end, grid_res)
        y = tf.linspace(y_start, y_end, grid_res)
        X, Y = tf.meshgrid(x, y)
        points = tf.stack([tf.reshape(X, [-1]), tf.reshape(Y, [-1])], axis=1)

        u_pred, v_pred, _ = self.model(points)
        u = tf.squeeze(u_pred).numpy()
        v = tf.squeeze(v_pred).numpy()

        vel_mag = np.sqrt(u**2 + v**2)
        min_idx = np.argmin(vel_mag)
        vortex_center = points[min_idx].numpy()

        print(f"{wall.capitalize()} wall vortex center approx at: x = {vortex_center[0]:.4f}, y = {vortex_center[1]:.4f}")
        return vortex_center

    def save_contour_plot(self, filename: str = 'velocity_contour.png', 
                         resolution: int = 1000, dpi: int = 300) -> None:
        """
        Save a high-quality contour plot of velocity magnitude.
        
        Args:
            filename: Output filename (can be .png or .pdf)
            resolution: Grid resolution
            dpi: Image resolution
        """
        x_plot = tf.linspace(self.config['domain']['x_min'], 
                            self.config['domain']['x_max'], 
                            resolution)
        y_plot = tf.linspace(self.config['domain']['y_min'], 
                            self.config['domain']['y_max'], 
                            resolution)
        X_grid, Y_grid = tf.meshgrid(x_plot, y_plot)
        XY = tf.stack([tf.reshape(X_grid, [-1]), tf.reshape(Y_grid, [-1])], axis=1)

        u_pred, v_pred, _ = self.model(XY)
        u_pred = tf.reshape(u_pred, (resolution, resolution)).numpy()
        v_pred = tf.reshape(v_pred, (resolution, resolution)).numpy()
        speed = np.sqrt(u_pred**2 + v_pred**2)

        fig, ax = plt.subplots(figsize=(5.5, 4), dpi=dpi)
        contour = ax.contourf(
            X_grid.numpy(), Y_grid.numpy(),
            speed,
            levels=100,
            cmap='coolwarm'
        )

        cbar = fig.colorbar(contour, ax=ax, pad=0.02)
        cbar.set_label('Velocity Magnitude', fontsize=10)

        ax.set_title('Velocity Magnitude Field', fontsize=11)
        ax.set_xlabel('x', fontsize=10)
        ax.set_ylabel('y', fontsize=10)
        ax.set_aspect('equal')
        ax.tick_params(labelsize=8)
        plt.tight_layout()
        plt.savefig(filename, dpi=dpi, bbox_inches='tight')
        plt.close()


    def plot_comparison_figure(self, ghia_data: dict, resolution: int = 50, dpi: int = 100, save_path: str = None) -> None:
        """
        Generate complete comparison figure with streamlines and validation plots.
    
        Args:
            ghia_data: Dictionary containing Ghia's benchmark data
            resolution: Resolution for streamline plot
            dpi: Figure resolution
            save_path: If provided, saves the figure to this path
        """
        fig = plt.figure(figsize=(15, 5), dpi=dpi)
        gs = fig.add_gridspec(1, 3)
        
        # Subplot a: Streamlines
        ax1 = fig.add_subplot(gs[0, 0])
        self._plot_streamlines(ax1, resolution)
        ax1.set_title('a) Predicted Streamlines (Re={})'.format(int(1/self.config['physics']['nu'])))
        
        # Subplot b: Vertical centerline
        ax2 = fig.add_subplot(gs[0, 1])
        self._plot_vertical_centerline(ax2, ghia_data)
        ax2.set_title('b) Vertical Centerline Velocity')
        
        # Subplot c: Horizontal centerline
        ax3 = fig.add_subplot(gs[0, 2])
        self._plot_horizontal_centerline(ax3, ghia_data)
        ax3.set_title('c) Horizontal Centerline Velocity')
        
        plt.tight_layout()
        
        if save_path is not None:
            plt.savefig(save_path, bbox_inches='tight')
            print(f"Figure saved to {save_path}")
        else:
            plt.show()
    


    def _plot_streamlines(self, ax, resolution: int) -> None:
        """Helper method to plot streamlines on given axis."""
        x_plot = tf.linspace(self.config['domain']['x_min'], 
                            self.config['domain']['x_max'], 
                            resolution)
        y_plot = tf.linspace(self.config['domain']['y_min'], 
                            self.config['domain']['y_max'], 
                            resolution)
        X_grid, Y_grid = tf.meshgrid(x_plot, y_plot)
        XY = tf.stack([tf.reshape(X_grid, [-1]), tf.reshape(Y_grid, [-1])], axis=1)

        u_pred, v_pred, _ = self.model(XY)
        u_pred = tf.reshape(u_pred, (resolution, resolution)).numpy()
        v_pred = tf.reshape(v_pred, (resolution, resolution)).numpy()

        ax.streamplot(
            X_grid.numpy(), Y_grid.numpy(),
            u_pred, v_pred, 
            density=2, 
            linewidth=1, 
            arrowsize=1,
            color=np.sqrt(u_pred**2 + v_pred**2),
            cmap='coolwarm'
        )
        ax.set_xlabel('x')
        ax.set_ylabel('y')
        ax.set_xlim(self.config['domain']['x_min'], self.config['domain']['x_max'])
        ax.set_ylim(self.config['domain']['y_min'], self.config['domain']['y_max'])
        ax.set_aspect('equal')

    def _plot_vertical_centerline(self, ax, ghia_data: dict, resolution: int = 100) -> None:
        """Helper method to plot vertical centerline comparison."""
        y_vertical = tf.linspace(self.config['domain']['y_min'], 
                               self.config['domain']['y_max'], 
                               resolution)
        x_vertical = 0.5 * (self.config['domain']['x_min'] + self.config['domain']['x_max']) * tf.ones_like(y_vertical)
        xy_vertical = tf.stack([x_vertical, y_vertical], axis=1)
        u_pred, _, _ = self.model(xy_vertical)
        
        ax.plot(u_pred.numpy().flatten(), y_vertical.numpy(), 'r-', label='PINN Prediction')
        ax.plot(ghia_data['u_vertical'][1], ghia_data['u_vertical'][0], 'ko', label='Ghia et al.')
        ax.set_xlabel('Horizontal Velocity (u)')
        ax.set_ylabel('y-coordinate')
        ax.legend()
        ax.grid(True)

    def _plot_horizontal_centerline(self, ax, ghia_data: dict, resolution: int = 100) -> None:
        """Helper method to plot horizontal centerline comparison."""
        x_horizontal = tf.linspace(self.config['domain']['x_min'], 
                                 self.config['domain']['x_max'], 
                                 resolution)
        y_horizontal = 0.5 * (self.config['domain']['y_min'] + self.config['domain']['y_max']) * tf.ones_like(x_horizontal)
        xy_horizontal = tf.stack([x_horizontal, y_horizontal], axis=1)
        _, v_pred, _ = self.model(xy_horizontal)
        
        ax.plot(x_horizontal.numpy(), v_pred.numpy().flatten(), 'b-', label='PINN Prediction')
        ax.plot(ghia_data['v_horizontal'][0], ghia_data['v_horizontal'][1], 'ko', label='Ghia et al.')
        ax.set_xlabel('x-coordinate')
        ax.set_ylabel('Vertical Velocity (v)')
        ax.legend()
        ax.grid(True)

    def plot_loss_history(self, log_scale: bool = True, figsize: Tuple[float, float] = (12, 6), save_path: str = None) -> None:
        """
        Plot the training loss history.
        
        Args:
            log_scale: Whether to use logarithmic scale for y-axis
            figsize: Figure size (width, height)
            save_path: If provided, saves the figure to this path
        """
        plt.figure(figsize=figsize)
        
        epochs = range(len(self.loss_history['total_loss']))
        
        if log_scale:
            plt.semilogy(epochs, self.loss_history['total_loss'], label='Total Loss')
            plt.semilogy(epochs, self.loss_history['pde_loss'], label='PDE Loss')
            plt.semilogy(epochs, self.loss_history['bc_loss'], label='BC Loss')
        else:
            plt.plot(epochs, self.loss_history['total_loss'], label='Total Loss')
            plt.plot(epochs, self.loss_history['pde_loss'], label='PDE Loss')
            plt.plot(epochs, self.loss_history['bc_loss'], label='BC Loss')
        
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Training Loss History')
        plt.legend()
        plt.grid(True, which="both", ls="-")
        plt.tight_layout()
        
        if save_path is not None:
            plt.savefig(save_path, bbox_inches='tight')
            print(f"Figure saved to {save_path}")
        else:
            plt.show()
     
    
    def get_loss_history(self) -> dict:
        """
        Return the complete loss history dictionary.
        
        Returns:
            Dictionary containing:
                'total_loss': List of total loss values
                'pde_loss': List of PDE loss values
                'bc_loss': List of boundary condition loss values
                'epoch_times': List of cumulative time per epoch
        """
        return self.loss_history
    
        
    
ghia_data_100 = {
    'u_vertical': (
        np.array([0.0000, 0.0547, 0.0625, 0.0703, 0.1016, 0.1719, 0.2813, 0.4531, 0.5000, 0.6172, 0.7344, 0.8516, 0.9531, 0.9609, 0.9688, 0.9766, 1.0000]),  # y positions
        np.array([0.00000, -0.03717, -0.04192, -0.04775, -0.06434, -0.10150, -0.15662, -0.21090, 0.20581, -0.13641, 0.00332, 0.23151, 0.68717, 0.73722, 0.78871, 0.84123, 1.00000])  # u velocities
    ),
    'v_horizontal': (
        np.array([0.0000, 0.0625, 0.0703, 0.0781, 0.0938, 0.1563, 0.2266, 0.2344, 0.5000, 0.8047, 0.8594, 0.9063, 0.9453, 0.9531, 0.9609, 0.9688, 1.0000]),  # x positions
        np.array([0.00000, 0.09233, 0.10091, 0.10890, 0.12317, 0.16077, 0.17507, 0.17527, 0.05454, -0.24533, -0.22445, -0.16914, -0.10313, -0.08864, -0.07391, -0.05906, 0.00000])  # v velocities
    )
}


ghia_data_400 = {
    'u_vertical': (
        np.array([0.0000, 0.0547, 0.0625, 0.0703, 0.1016, 0.1719, 0.2813, 0.4531, 0.5000, 0.6172, 0.7344, 0.8516, 0.9531, 0.9609, 0.9688, 0.9766, 1.0000]),  # y positions
        np.array([0.00000, -0.08186, -0.09266, -0.10338, -0.14612, -0.24299, -0.32726, -0.17119, -0.11477, 0.02135, 0.16256, 0.29093, 0.55892, 0.61756, 0.68439, 0.75837, 1.00000])  # u velocities
    ),
    'v_horizontal': (
        np.array([0.0000, 0.0625, 0.0703, 0.0781, 0.0938, 0.1563, 0.2266, 0.2344, 0.5000, 0.8047, 0.8594, 0.9063, 0.9453, 0.9531, 0.9609, 0.9688, 1.0000]),  # x positions
        np.array([0.00000, 0.18360, 0.19713, 0.20920, 0.22965, 0.28124, 0.30203, 0.30174, 0.05186, -0.38598, -0.44993, -0.23827, -0.22847, -0.19254, -0.15663, -0.12146, 0.00000])  # v velocities
    )
}

ghia_data_1000 = {
    'u_vertical': (
        np.array([0.0000, 0.0547, 0.0625, 0.0703, 0.1016, 0.1719, 0.2813, 0.4531, 0.5000, 0.6172, 0.7344, 0.8516, 0.9531, 0.9609, 0.9688, 0.9766, 1.0000]),  # y positions
        np.array([0.00000, -0.18109, -0.20196, -0.22220, -0.29730, -0.38289, -0.27805, 0.10648, 0.31683, 0.38857, 0.30070, 0.10890, -0.05702, -0.07404, -0.08823, -0.09947, 0.00000])  # u velocities
    ),
    'v_horizontal': (
        np.array([0.0000, 0.0625, 0.0703, 0.0781, 0.0938, 0.1563, 0.2266, 0.2344, 0.5000, 0.8047, 0.8594, 0.9063, 0.9453, 0.9531, 0.9609, 0.9688, 1.0000]),  # x positions
        np.array([0.00000, 0.27485, 0.29012, 0.30353, 0.32627, 0.37095, 0.33075, 0.32235, 0.02526, -0.31966, -0.42665, -0.51550, -0.39188, -0.33714, -0.27669, -0.21388, 0.00000])  # v velocities
    )
}
# Out:
# C:\Users\sandh\anaconda3\envs\py310\lib\site-packages\tensorflow\python\keras\engine\training_arrays_v1.py:37: UserWarning: A NumPy version >=1.23.5 and <2.5.0 is required for this version of SciPy (detected version 1.23.0)
#   from scipy.sparse import issparse  # pylint: disable=g-import-not-at-top

# %%
# Example usage
config = {
            'domain': {
                'x_min': 0.0,
                'x_max': 1.0,
                'y_min': 0.0,
                'y_max': 1.0
            },
            'physics': {
                'U_lid': 1.0,
                'nu': 0.001  # kinematic viscosity( re number 100)
            },
            'training': {
                'N_f': 10000,  # Number of collocation points
                'N_b': 500,   # Number of boundary points
                'target_loss': 0.001,
                'max_epochs': 50000,
                'learning_rate': 8e-4
            },
            'model': {
                'num_shared_layers': 6,
                'num_head_layers': 2,
                'num_neurons': 40,
                'activation': 'tanh'
            }
        }

# %%
# Create and train PINN
pinn = LidDrivenCavityPINN(config)  # Re=1000
pinn.train()
# Out:
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# WARNING:tensorflow:Gradients do not exist for variables ['dense_14/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_14/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# Epoch 0: Total Loss = 1.1072e+00, PDE Loss = 6.8522e-01, BC Loss = 4.2193e-01
# Epoch 100: Total Loss = 6.9735e-02, PDE Loss = 1.9275e-03, BC Loss = 6.7807e-02
# Epoch 200: Total Loss = 1.7262e-02, PDE Loss = 2.0203e-03, BC Loss = 1.5242e-02
# Epoch 300: Total Loss = 8.8131e-03, PDE Loss = 9.7585e-04, BC Loss = 7.8373e-03
# Epoch 400: Total Loss = 6.8382e-03, PDE Loss = 9.5376e-04, BC Loss = 5.8844e-03
# Epoch 500: Total Loss = 6.5407e-03, PDE Loss = 1.2584e-03, BC Loss = 5.2823e-03
# Epoch 600: Total Loss = 5.8466e-03, PDE Loss = 7.9794e-04, BC Loss = 5.0487e-03
# Epoch 700: Total Loss = 6.8691e-03, PDE Loss = 1.4418e-03, BC Loss = 5.4273e-03
# Epoch 800: Total Loss = 6.3923e-03, PDE Loss = 8.6488e-04, BC Loss = 5.5274e-03
# Epoch 900: Total Loss = 5.2018e-03, PDE Loss = 5.7776e-04, BC Loss = 4.6240e-03
# Epoch 1000: Total Loss = 5.8954e-03, PDE Loss = 6.5492e-04, BC Loss = 5.2404e-03
# Epoch 1100: Total Loss = 1.0625e-02, PDE Loss = 1.1960e-03, BC Loss = 9.4289e-03
# Epoch 1200: Total Loss = 4.6938e-03, PDE Loss = 4.6241e-04, BC Loss = 4.2313e-03
# Epoch 1300: Total Loss = 4.6878e-03, PDE Loss = 3.7244e-04, BC Loss = 4.3153e-03
# Epoch 1400: Total Loss = 4.4943e-03, PDE Loss = 3.5179e-04, BC Loss = 4.1425e-03
# Epoch 1500: Total Loss = 7.1119e-03, PDE Loss = 1.4273e-03, BC Loss = 5.6845e-03
# Epoch 1600: Total Loss = 5.1284e-03, PDE Loss = 7.6000e-04, BC Loss = 4.3683e-03
# Epoch 1700: Total Loss = 4.6122e-03, PDE Loss = 3.1019e-04, BC Loss = 4.3020e-03
# Epoch 1800: Total Loss = 4.7059e-03, PDE Loss = 3.4335e-04, BC Loss = 4.3626e-03
# Epoch 1900: Total Loss = 1.8566e-02, PDE Loss = 2.1509e-03, BC Loss = 1.6415e-02
# Epoch 2000: Total Loss = 6.4436e-03, PDE Loss = 7.2086e-04, BC Loss = 5.7227e-03
# Epoch 2100: Total Loss = 5.3843e-03, PDE Loss = 4.0149e-04, BC Loss = 4.9828e-03
# Epoch 2200: Total Loss = 5.9684e-03, PDE Loss = 1.9625e-03, BC Loss = 4.0058e-03
# Epoch 2300: Total Loss = 4.0428e-03, PDE Loss = 2.4717e-04, BC Loss = 3.7956e-03
# Epoch 2400: Total Loss = 4.3255e-03, PDE Loss = 4.5191e-04, BC Loss = 3.8736e-03
# Epoch 2500: Total Loss = 4.2390e-03, PDE Loss = 2.4448e-04, BC Loss = 3.9945e-03
# Epoch 2600: Total Loss = 3.9999e-03, PDE Loss = 3.1713e-04, BC Loss = 3.6827e-03
# Epoch 2700: Total Loss = 5.9820e-03, PDE Loss = 5.0646e-04, BC Loss = 5.4756e-03
# Epoch 2800: Total Loss = 3.9137e-03, PDE Loss = 2.6291e-04, BC Loss = 3.6508e-03
# Epoch 2900: Total Loss = 5.3309e-03, PDE Loss = 5.9099e-04, BC Loss = 4.7399e-03
# Epoch 3000: Total Loss = 5.9336e-03, PDE Loss = 2.6129e-04, BC Loss = 5.6723e-03
# Epoch 3100: Total Loss = 3.7449e-03, PDE Loss = 3.3837e-04, BC Loss = 3.4066e-03
# Epoch 3200: Total Loss = 4.3572e-03, PDE Loss = 2.0008e-04, BC Loss = 4.1572e-03
# Epoch 3300: Total Loss = 4.2070e-03, PDE Loss = 3.7849e-04, BC Loss = 3.8285e-03
# Epoch 3400: Total Loss = 1.9611e-02, PDE Loss = 2.9964e-03, BC Loss = 1.6614e-02
# Epoch 3500: Total Loss = 4.1082e-03, PDE Loss = 4.1711e-04, BC Loss = 3.6911e-03
# Epoch 3600: Total Loss = 4.7747e-03, PDE Loss = 3.2958e-04, BC Loss = 4.4452e-03
# Epoch 3700: Total Loss = 4.3943e-03, PDE Loss = 4.3482e-04, BC Loss = 3.9595e-03
# Epoch 3800: Total Loss = 3.9500e-03, PDE Loss = 2.2550e-04, BC Loss = 3.7245e-03
# Epoch 3900: Total Loss = 4.2582e-03, PDE Loss = 3.0765e-04, BC Loss = 3.9505e-03
# Epoch 4000: Total Loss = 3.5407e-03, PDE Loss = 2.8516e-04, BC Loss = 3.2555e-03
# Epoch 4100: Total Loss = 3.7217e-03, PDE Loss = 3.0542e-04, BC Loss = 3.4162e-03
# Epoch 4200: Total Loss = 3.6568e-03, PDE Loss = 2.6877e-04, BC Loss = 3.3880e-03
# Epoch 4300: Total Loss = 3.8267e-03, PDE Loss = 3.2154e-04, BC Loss = 3.5051e-03
# Epoch 4400: Total Loss = 4.1472e-03, PDE Loss = 2.6465e-04, BC Loss = 3.8825e-03
# Epoch 4500: Total Loss = 4.1037e-03, PDE Loss = 8.1536e-04, BC Loss = 3.2883e-03
# Epoch 4600: Total Loss = 3.5797e-03, PDE Loss = 2.8754e-04, BC Loss = 3.2922e-03
# Epoch 4700: Total Loss = 3.9688e-03, PDE Loss = 3.1840e-04, BC Loss = 3.6504e-03
# Epoch 4800: Total Loss = 3.4609e-03, PDE Loss = 4.0043e-04, BC Loss = 3.0605e-03
# Epoch 4900: Total Loss = 3.8863e-03, PDE Loss = 4.2517e-04, BC Loss = 3.4611e-03
# Epoch 5000: Total Loss = 3.4237e-03, PDE Loss = 3.3042e-04, BC Loss = 3.0932e-03
# Epoch 5100: Total Loss = 3.4214e-03, PDE Loss = 3.0724e-04, BC Loss = 3.1142e-03
# Epoch 5200: Total Loss = 4.1919e-03, PDE Loss = 3.0829e-04, BC Loss = 3.8836e-03
# Epoch 5300: Total Loss = 7.7756e-03, PDE Loss = 8.0531e-04, BC Loss = 6.9703e-03
# Epoch 5400: Total Loss = 3.3626e-03, PDE Loss = 3.2085e-04, BC Loss = 3.0417e-03
# Epoch 5500: Total Loss = 4.2450e-03, PDE Loss = 4.7531e-04, BC Loss = 3.7697e-03
# Epoch 5600: Total Loss = 3.3848e-03, PDE Loss = 3.0803e-04, BC Loss = 3.0768e-03
# Epoch 5700: Total Loss = 6.1947e-03, PDE Loss = 5.3767e-04, BC Loss = 5.6570e-03
# Epoch 5800: Total Loss = 6.3874e-03, PDE Loss = 2.6724e-04, BC Loss = 6.1201e-03
# Epoch 5900: Total Loss = 3.4717e-03, PDE Loss = 3.2786e-04, BC Loss = 3.1439e-03
# Epoch 6000: Total Loss = 4.2106e-03, PDE Loss = 4.0967e-04, BC Loss = 3.8009e-03
# Epoch 6100: Total Loss = 3.7474e-03, PDE Loss = 5.6969e-04, BC Loss = 3.1777e-03
# Epoch 6200: Total Loss = 3.8483e-03, PDE Loss = 8.3697e-04, BC Loss = 3.0113e-03
# Epoch 6300: Total Loss = 4.8719e-03, PDE Loss = 4.5362e-04, BC Loss = 4.4183e-03
# Epoch 6400: Total Loss = 3.3485e-03, PDE Loss = 5.7573e-04, BC Loss = 2.7728e-03
# Epoch 6500: Total Loss = 3.1998e-03, PDE Loss = 3.3729e-04, BC Loss = 2.8625e-03
# Epoch 6600: Total Loss = 3.2269e-03, PDE Loss = 4.0366e-04, BC Loss = 2.8233e-03
# Epoch 6700: Total Loss = 2.9026e-03, PDE Loss = 2.9785e-04, BC Loss = 2.6047e-03
# Epoch 6800: Total Loss = 3.2078e-03, PDE Loss = 3.8093e-04, BC Loss = 2.8269e-03
# Epoch 6900: Total Loss = 3.2999e-03, PDE Loss = 5.2482e-04, BC Loss = 2.7750e-03
# Epoch 7000: Total Loss = 7.9007e-03, PDE Loss = 4.4123e-03, BC Loss = 3.4884e-03
# Epoch 7100: Total Loss = 4.7367e-03, PDE Loss = 3.7520e-04, BC Loss = 4.3615e-03
# Epoch 7200: Total Loss = 3.0678e-03, PDE Loss = 2.8049e-04, BC Loss = 2.7873e-03
# Epoch 7300: Total Loss = 3.3348e-03, PDE Loss = 5.5703e-04, BC Loss = 2.7777e-03
# Epoch 7400: Total Loss = 4.4217e-03, PDE Loss = 1.6545e-03, BC Loss = 2.7671e-03
# Epoch 7500: Total Loss = 4.6642e-03, PDE Loss = 5.5754e-04, BC Loss = 4.1067e-03
# Epoch 7600: Total Loss = 3.3844e-03, PDE Loss = 6.8652e-04, BC Loss = 2.6979e-03
# Epoch 7700: Total Loss = 3.3842e-03, PDE Loss = 3.7117e-04, BC Loss = 3.0131e-03
# Epoch 7800: Total Loss = 2.8995e-03, PDE Loss = 3.7357e-04, BC Loss = 2.5259e-03
# Epoch 7900: Total Loss = 3.2422e-03, PDE Loss = 4.4154e-04, BC Loss = 2.8007e-03
# Epoch 8000: Total Loss = 2.6455e-03, PDE Loss = 3.9413e-04, BC Loss = 2.2514e-03
# Epoch 8100: Total Loss = 3.2228e-03, PDE Loss = 8.2240e-04, BC Loss = 2.4004e-03
# Epoch 8200: Total Loss = 3.1920e-03, PDE Loss = 5.3229e-04, BC Loss = 2.6597e-03
# Epoch 8300: Total Loss = 2.5725e-03, PDE Loss = 3.8118e-04, BC Loss = 2.1913e-03
# Epoch 8400: Total Loss = 4.9787e-03, PDE Loss = 8.8145e-04, BC Loss = 4.0972e-03
# Epoch 8500: Total Loss = 2.6798e-03, PDE Loss = 4.9005e-04, BC Loss = 2.1897e-03
# Epoch 8600: Total Loss = 2.7654e-03, PDE Loss = 3.4170e-04, BC Loss = 2.4237e-03
# Epoch 8700: Total Loss = 4.1164e-03, PDE Loss = 3.8232e-04, BC Loss = 3.7341e-03
# Epoch 8800: Total Loss = 4.4092e-03, PDE Loss = 4.6325e-04, BC Loss = 3.9460e-03
# Epoch 8900: Total Loss = 3.4087e-03, PDE Loss = 8.4864e-04, BC Loss = 2.5601e-03
# Epoch 9000: Total Loss = 2.4795e-03, PDE Loss = 4.1732e-04, BC Loss = 2.0622e-03
# Epoch 9100: Total Loss = 2.6138e-03, PDE Loss = 4.9093e-04, BC Loss = 2.1229e-03
# Epoch 9200: Total Loss = 2.6957e-03, PDE Loss = 4.3312e-04, BC Loss = 2.2626e-03
# Epoch 9300: Total Loss = 3.2058e-03, PDE Loss = 3.6092e-04, BC Loss = 2.8448e-03
# Epoch 9400: Total Loss = 2.7839e-03, PDE Loss = 5.0778e-04, BC Loss = 2.2761e-03
# Epoch 9500: Total Loss = 2.6896e-03, PDE Loss = 3.6300e-04, BC Loss = 2.3266e-03
# Epoch 9600: Total Loss = 2.3621e-03, PDE Loss = 3.2386e-04, BC Loss = 2.0383e-03
# Epoch 9700: Total Loss = 3.1514e-03, PDE Loss = 3.5805e-04, BC Loss = 2.7933e-03
# Epoch 9800: Total Loss = 2.7635e-03, PDE Loss = 3.2746e-04, BC Loss = 2.4360e-03
# Epoch 9900: Total Loss = 3.6659e-03, PDE Loss = 4.5617e-04, BC Loss = 3.2097e-03
# Epoch 10000: Total Loss = 2.3798e-03, PDE Loss = 2.7403e-04, BC Loss = 2.1057e-03
# Epoch 10100: Total Loss = 2.9083e-03, PDE Loss = 7.7531e-04, BC Loss = 2.1330e-03
# Epoch 10200: Total Loss = 2.4956e-03, PDE Loss = 2.7332e-04, BC Loss = 2.2223e-03
# Epoch 10300: Total Loss = 4.5480e-03, PDE Loss = 4.8061e-04, BC Loss = 4.0674e-03
# Epoch 10400: Total Loss = 2.4176e-03, PDE Loss = 2.9838e-04, BC Loss = 2.1193e-03
# Epoch 10500: Total Loss = 2.8407e-03, PDE Loss = 4.9544e-04, BC Loss = 2.3452e-03
# Epoch 10600: Total Loss = 2.7225e-03, PDE Loss = 3.8674e-04, BC Loss = 2.3358e-03
# Epoch 10700: Total Loss = 2.5110e-03, PDE Loss = 2.5641e-04, BC Loss = 2.2546e-03
# Epoch 10800: Total Loss = 2.2691e-03, PDE Loss = 2.7777e-04, BC Loss = 1.9914e-03
# Epoch 10900: Total Loss = 2.8383e-03, PDE Loss = 3.3094e-04, BC Loss = 2.5074e-03
# Epoch 11000: Total Loss = 2.2621e-03, PDE Loss = 2.4150e-04, BC Loss = 2.0206e-03
# Epoch 11100: Total Loss = 2.2849e-03, PDE Loss = 2.2215e-04, BC Loss = 2.0627e-03
# Epoch 11200: Total Loss = 2.1707e-03, PDE Loss = 3.0720e-04, BC Loss = 1.8635e-03
# Epoch 11300: Total Loss = 2.6767e-03, PDE Loss = 4.3347e-04, BC Loss = 2.2432e-03
# Epoch 11400: Total Loss = 2.4327e-03, PDE Loss = 5.9336e-04, BC Loss = 1.8394e-03
# Epoch 11500: Total Loss = 4.8529e-03, PDE Loss = 8.1293e-04, BC Loss = 4.0400e-03
# Epoch 11600: Total Loss = 2.5929e-03, PDE Loss = 2.6757e-04, BC Loss = 2.3253e-03
# Epoch 11700: Total Loss = 2.7599e-03, PDE Loss = 4.5895e-04, BC Loss = 2.3009e-03
# Epoch 11800: Total Loss = 2.9829e-03, PDE Loss = 4.9772e-04, BC Loss = 2.4852e-03
# Epoch 11900: Total Loss = 2.2181e-03, PDE Loss = 3.8103e-04, BC Loss = 1.8370e-03
# Epoch 12000: Total Loss = 3.1322e-03, PDE Loss = 6.7872e-04, BC Loss = 2.4535e-03
# Epoch 12100: Total Loss = 2.1769e-03, PDE Loss = 2.1768e-04, BC Loss = 1.9592e-03
# Epoch 12200: Total Loss = 2.3170e-03, PDE Loss = 2.6278e-04, BC Loss = 2.0542e-03
# Epoch 12300: Total Loss = 2.1757e-03, PDE Loss = 2.8752e-04, BC Loss = 1.8882e-03
# Epoch 12400: Total Loss = 2.3247e-03, PDE Loss = 2.8719e-04, BC Loss = 2.0375e-03
# Epoch 12500: Total Loss = 2.5262e-03, PDE Loss = 3.7317e-04, BC Loss = 2.1530e-03
# Epoch 12600: Total Loss = 2.2249e-03, PDE Loss = 2.3618e-04, BC Loss = 1.9887e-03
# Epoch 12700: Total Loss = 2.0613e-03, PDE Loss = 3.4459e-04, BC Loss = 1.7167e-03
# Epoch 12800: Total Loss = 2.5948e-03, PDE Loss = 2.0817e-04, BC Loss = 2.3867e-03
# Epoch 12900: Total Loss = 2.2007e-03, PDE Loss = 3.4202e-04, BC Loss = 1.8586e-03
# Epoch 13000: Total Loss = 2.7556e-03, PDE Loss = 2.3545e-04, BC Loss = 2.5201e-03
# Epoch 13100: Total Loss = 2.1704e-03, PDE Loss = 1.8706e-04, BC Loss = 1.9834e-03
# Epoch 13200: Total Loss = 2.3962e-03, PDE Loss = 5.1445e-04, BC Loss = 1.8818e-03
# Epoch 13300: Total Loss = 2.2848e-03, PDE Loss = 3.9548e-04, BC Loss = 1.8893e-03
# Epoch 13400: Total Loss = 2.4310e-03, PDE Loss = 4.1575e-04, BC Loss = 2.0153e-03
# Epoch 13500: Total Loss = 2.2454e-03, PDE Loss = 5.2489e-04, BC Loss = 1.7205e-03
# Epoch 13600: Total Loss = 2.2674e-03, PDE Loss = 3.3859e-04, BC Loss = 1.9288e-03
# Epoch 13700: Total Loss = 2.3365e-03, PDE Loss = 4.4599e-04, BC Loss = 1.8905e-03
# Epoch 13800: Total Loss = 1.8685e-03, PDE Loss = 2.3381e-04, BC Loss = 1.6347e-03
# Epoch 13900: Total Loss = 4.4160e-03, PDE Loss = 1.0638e-03, BC Loss = 3.3522e-03
# Epoch 14000: Total Loss = 1.9675e-03, PDE Loss = 2.1380e-04, BC Loss = 1.7537e-03
# Epoch 14100: Total Loss = 2.1426e-03, PDE Loss = 1.9550e-04, BC Loss = 1.9471e-03
# Epoch 14200: Total Loss = 2.7271e-03, PDE Loss = 3.8305e-04, BC Loss = 2.3440e-03
# Epoch 14300: Total Loss = 2.0561e-03, PDE Loss = 3.2109e-04, BC Loss = 1.7350e-03
# Epoch 14400: Total Loss = 2.3240e-03, PDE Loss = 5.3527e-04, BC Loss = 1.7887e-03
# Epoch 14500: Total Loss = 2.0234e-03, PDE Loss = 2.9780e-04, BC Loss = 1.7256e-03
# Epoch 14600: Total Loss = 2.5495e-03, PDE Loss = 2.6350e-04, BC Loss = 2.2860e-03
# Epoch 14700: Total Loss = 1.9068e-03, PDE Loss = 2.7840e-04, BC Loss = 1.6284e-03
# Epoch 14800: Total Loss = 1.8866e-03, PDE Loss = 2.3358e-04, BC Loss = 1.6530e-03
# Epoch 14900: Total Loss = 2.1543e-03, PDE Loss = 4.9511e-04, BC Loss = 1.6592e-03
# Epoch 15000: Total Loss = 1.8541e-03, PDE Loss = 1.9708e-04, BC Loss = 1.6571e-03
# Epoch 15100: Total Loss = 2.1838e-03, PDE Loss = 4.5882e-04, BC Loss = 1.7250e-03
# Epoch 15200: Total Loss = 2.8675e-03, PDE Loss = 3.5646e-04, BC Loss = 2.5110e-03
# Epoch 15300: Total Loss = 2.2947e-03, PDE Loss = 3.1015e-04, BC Loss = 1.9846e-03
# Epoch 15400: Total Loss = 2.5587e-03, PDE Loss = 2.2717e-04, BC Loss = 2.3315e-03
# Epoch 15500: Total Loss = 1.9778e-03, PDE Loss = 4.0813e-04, BC Loss = 1.5697e-03
# Epoch 15600: Total Loss = 2.6319e-03, PDE Loss = 2.3018e-04, BC Loss = 2.4017e-03
# Epoch 15700: Total Loss = 1.7357e-03, PDE Loss = 2.2689e-04, BC Loss = 1.5088e-03
# Epoch 15800: Total Loss = 1.8634e-03, PDE Loss = 3.5265e-04, BC Loss = 1.5108e-03
# Epoch 15900: Total Loss = 2.1648e-03, PDE Loss = 3.1425e-04, BC Loss = 1.8506e-03
# Epoch 16000: Total Loss = 2.4130e-03, PDE Loss = 2.6906e-04, BC Loss = 2.1440e-03
# Epoch 16100: Total Loss = 2.1204e-03, PDE Loss = 2.9103e-04, BC Loss = 1.8294e-03
# Epoch 16200: Total Loss = 2.0522e-03, PDE Loss = 3.9473e-04, BC Loss = 1.6575e-03
# Epoch 16300: Total Loss = 2.1088e-03, PDE Loss = 2.7673e-04, BC Loss = 1.8321e-03
# Epoch 16400: Total Loss = 2.0690e-03, PDE Loss = 2.7375e-04, BC Loss = 1.7952e-03
# Epoch 16500: Total Loss = 3.6789e-03, PDE Loss = 3.5128e-04, BC Loss = 3.3276e-03
# Epoch 16600: Total Loss = 2.4441e-03, PDE Loss = 3.9888e-04, BC Loss = 2.0453e-03
# Epoch 16700: Total Loss = 2.0628e-03, PDE Loss = 5.7977e-04, BC Loss = 1.4831e-03
# Epoch 16800: Total Loss = 2.1605e-03, PDE Loss = 3.8007e-04, BC Loss = 1.7805e-03
# Epoch 16900: Total Loss = 2.1543e-03, PDE Loss = 2.5947e-04, BC Loss = 1.8948e-03
# Epoch 17000: Total Loss = 2.6856e-03, PDE Loss = 2.6533e-04, BC Loss = 2.4202e-03
# Epoch 17100: Total Loss = 1.9199e-03, PDE Loss = 2.3127e-04, BC Loss = 1.6887e-03
# Epoch 17200: Total Loss = 2.0405e-03, PDE Loss = 3.8337e-04, BC Loss = 1.6571e-03
# Epoch 17300: Total Loss = 1.7844e-03, PDE Loss = 2.7433e-04, BC Loss = 1.5100e-03
# Epoch 17400: Total Loss = 1.7535e-03, PDE Loss = 2.5514e-04, BC Loss = 1.4984e-03
# Epoch 17500: Total Loss = 2.4864e-03, PDE Loss = 2.8848e-04, BC Loss = 2.1979e-03
# Epoch 17600: Total Loss = 2.3168e-03, PDE Loss = 3.0306e-04, BC Loss = 2.0137e-03
# Epoch 17700: Total Loss = 1.8058e-03, PDE Loss = 2.8892e-04, BC Loss = 1.5169e-03
# Epoch 17800: Total Loss = 1.9203e-03, PDE Loss = 2.4375e-04, BC Loss = 1.6765e-03
# Epoch 17900: Total Loss = 4.6920e-03, PDE Loss = 1.0153e-03, BC Loss = 3.6766e-03
# Epoch 18000: Total Loss = 1.6883e-03, PDE Loss = 1.8116e-04, BC Loss = 1.5072e-03
# Epoch 18100: Total Loss = 2.3036e-03, PDE Loss = 2.8318e-04, BC Loss = 2.0204e-03
# Epoch 18200: Total Loss = 1.7229e-03, PDE Loss = 2.1894e-04, BC Loss = 1.5040e-03
# Epoch 18300: Total Loss = 1.8535e-03, PDE Loss = 2.1660e-04, BC Loss = 1.6369e-03
# Epoch 18400: Total Loss = 2.5540e-03, PDE Loss = 3.1016e-04, BC Loss = 2.2438e-03
# Epoch 18500: Total Loss = 5.5417e-03, PDE Loss = 5.6732e-04, BC Loss = 4.9744e-03
# Epoch 18600: Total Loss = 1.6957e-03, PDE Loss = 2.1215e-04, BC Loss = 1.4835e-03
# Epoch 18700: Total Loss = 1.7723e-03, PDE Loss = 1.8054e-04, BC Loss = 1.5917e-03
# Epoch 18800: Total Loss = 2.2102e-03, PDE Loss = 2.6866e-04, BC Loss = 1.9415e-03
# Epoch 18900: Total Loss = 2.6013e-03, PDE Loss = 3.3833e-04, BC Loss = 2.2629e-03
# Epoch 19000: Total Loss = 1.6469e-03, PDE Loss = 1.8013e-04, BC Loss = 1.4667e-03
# Epoch 19100: Total Loss = 1.6393e-03, PDE Loss = 2.3914e-04, BC Loss = 1.4002e-03
# Epoch 19200: Total Loss = 2.1169e-03, PDE Loss = 3.0197e-04, BC Loss = 1.8150e-03
# Epoch 19300: Total Loss = 2.2053e-03, PDE Loss = 4.4594e-04, BC Loss = 1.7594e-03
# Epoch 19400: Total Loss = 1.7878e-03, PDE Loss = 2.0030e-04, BC Loss = 1.5874e-03
# Epoch 19500: Total Loss = 2.3550e-03, PDE Loss = 2.6761e-04, BC Loss = 2.0874e-03
# Epoch 19600: Total Loss = 1.6194e-03, PDE Loss = 2.2301e-04, BC Loss = 1.3964e-03
# Epoch 19700: Total Loss = 1.5740e-03, PDE Loss = 1.5691e-04, BC Loss = 1.4170e-03
# Epoch 19800: Total Loss = 2.4941e-03, PDE Loss = 2.3005e-04, BC Loss = 2.2640e-03
# Epoch 19900: Total Loss = 3.1709e-03, PDE Loss = 4.4979e-04, BC Loss = 2.7211e-03
# Epoch 20000: Total Loss = 1.6077e-03, PDE Loss = 1.8225e-04, BC Loss = 1.4254e-03
# Epoch 20100: Total Loss = 1.8945e-03, PDE Loss = 3.4499e-04, BC Loss = 1.5495e-03
# Epoch 20200: Total Loss = 1.7822e-03, PDE Loss = 1.9778e-04, BC Loss = 1.5844e-03
# Epoch 20300: Total Loss = 1.8357e-03, PDE Loss = 3.4362e-04, BC Loss = 1.4920e-03
# Epoch 20400: Total Loss = 1.5590e-03, PDE Loss = 1.6549e-04, BC Loss = 1.3935e-03
# Epoch 20500: Total Loss = 1.5167e-03, PDE Loss = 1.5020e-04, BC Loss = 1.3665e-03
# Epoch 20600: Total Loss = 1.8258e-03, PDE Loss = 2.9928e-04, BC Loss = 1.5265e-03
# Epoch 20700: Total Loss = 1.8285e-03, PDE Loss = 3.9053e-04, BC Loss = 1.4380e-03
# Epoch 20800: Total Loss = 1.7929e-03, PDE Loss = 2.1029e-04, BC Loss = 1.5826e-03
# Epoch 20900: Total Loss = 1.6532e-03, PDE Loss = 2.1825e-04, BC Loss = 1.4350e-03
# Epoch 21000: Total Loss = 2.0686e-03, PDE Loss = 3.1364e-04, BC Loss = 1.7549e-03
# Epoch 21100: Total Loss = 8.4357e-03, PDE Loss = 2.2177e-03, BC Loss = 6.2180e-03
# Epoch 21200: Total Loss = 2.6522e-03, PDE Loss = 5.3014e-04, BC Loss = 2.1220e-03
# Epoch 21300: Total Loss = 1.6404e-03, PDE Loss = 1.7869e-04, BC Loss = 1.4617e-03
# Epoch 21400: Total Loss = 2.2095e-03, PDE Loss = 2.2938e-04, BC Loss = 1.9802e-03
# Epoch 21500: Total Loss = 7.3494e-03, PDE Loss = 2.9912e-04, BC Loss = 7.0503e-03
# Epoch 21600: Total Loss = 1.9856e-03, PDE Loss = 3.1698e-04, BC Loss = 1.6686e-03
# Epoch 21700: Total Loss = 1.8111e-03, PDE Loss = 2.4067e-04, BC Loss = 1.5704e-03
# Epoch 21800: Total Loss = 2.0959e-03, PDE Loss = 2.7299e-04, BC Loss = 1.8230e-03
# Epoch 21900: Total Loss = 1.6742e-03, PDE Loss = 2.1850e-04, BC Loss = 1.4557e-03
# Epoch 22000: Total Loss = 1.9173e-03, PDE Loss = 3.1998e-04, BC Loss = 1.5973e-03
# Epoch 22100: Total Loss = 1.5996e-03, PDE Loss = 2.0031e-04, BC Loss = 1.3993e-03
# Epoch 22200: Total Loss = 2.4674e-03, PDE Loss = 3.0124e-04, BC Loss = 2.1662e-03
# Epoch 22300: Total Loss = 2.4268e-03, PDE Loss = 4.8971e-04, BC Loss = 1.9371e-03
# Epoch 22400: Total Loss = 1.4918e-03, PDE Loss = 2.2542e-04, BC Loss = 1.2663e-03
# Epoch 22500: Total Loss = 1.6358e-03, PDE Loss = 2.2959e-04, BC Loss = 1.4062e-03
# Epoch 22600: Total Loss = 2.0335e-03, PDE Loss = 3.0101e-04, BC Loss = 1.7325e-03
# Epoch 22700: Total Loss = 2.5517e-03, PDE Loss = 4.4045e-04, BC Loss = 2.1112e-03
# Epoch 22800: Total Loss = 3.9347e-03, PDE Loss = 5.9708e-04, BC Loss = 3.3376e-03
# Epoch 22900: Total Loss = 1.8248e-03, PDE Loss = 5.5385e-04, BC Loss = 1.2709e-03
# Epoch 23000: Total Loss = 2.2648e-03, PDE Loss = 3.6829e-04, BC Loss = 1.8965e-03
# Epoch 23100: Total Loss = 3.2924e-03, PDE Loss = 9.2253e-04, BC Loss = 2.3699e-03
# Epoch 23200: Total Loss = 2.9288e-03, PDE Loss = 5.7225e-04, BC Loss = 2.3566e-03
# Epoch 23300: Total Loss = 1.4251e-03, PDE Loss = 1.9633e-04, BC Loss = 1.2288e-03
# Epoch 23400: Total Loss = 2.0351e-03, PDE Loss = 1.9081e-04, BC Loss = 1.8443e-03
# Epoch 23500: Total Loss = 1.9934e-03, PDE Loss = 2.5225e-04, BC Loss = 1.7411e-03
# Epoch 23600: Total Loss = 2.4057e-03, PDE Loss = 3.7280e-04, BC Loss = 2.0329e-03
# Epoch 23700: Total Loss = 1.5264e-03, PDE Loss = 3.1342e-04, BC Loss = 1.2130e-03
# Epoch 23800: Total Loss = 1.9606e-03, PDE Loss = 3.2122e-04, BC Loss = 1.6393e-03
# Epoch 23900: Total Loss = 2.8712e-03, PDE Loss = 4.1552e-04, BC Loss = 2.4557e-03
# Epoch 24000: Total Loss = 1.7978e-03, PDE Loss = 2.0548e-04, BC Loss = 1.5923e-03
# Epoch 24100: Total Loss = 4.7238e-03, PDE Loss = 3.5672e-04, BC Loss = 4.3671e-03
# Epoch 24200: Total Loss = 1.7942e-03, PDE Loss = 4.3095e-04, BC Loss = 1.3632e-03
# Epoch 24300: Total Loss = 1.5424e-03, PDE Loss = 3.2744e-04, BC Loss = 1.2149e-03
# Epoch 24400: Total Loss = 1.6714e-03, PDE Loss = 2.5011e-04, BC Loss = 1.4213e-03
# Epoch 24500: Total Loss = 1.4445e-03, PDE Loss = 1.6949e-04, BC Loss = 1.2750e-03
# Epoch 24600: Total Loss = 1.5666e-03, PDE Loss = 2.0211e-04, BC Loss = 1.3645e-03
# Epoch 24700: Total Loss = 2.0300e-03, PDE Loss = 3.4757e-04, BC Loss = 1.6824e-03
# Epoch 24800: Total Loss = 2.2217e-03, PDE Loss = 2.8047e-04, BC Loss = 1.9412e-03
# Epoch 24900: Total Loss = 2.4025e-03, PDE Loss = 9.7958e-04, BC Loss = 1.4229e-03
# Epoch 25000: Total Loss = 2.5781e-03, PDE Loss = 2.5423e-04, BC Loss = 2.3239e-03
# Epoch 25100: Total Loss = 1.9002e-03, PDE Loss = 4.2173e-04, BC Loss = 1.4784e-03
# Epoch 25200: Total Loss = 1.7614e-03, PDE Loss = 2.1227e-04, BC Loss = 1.5491e-03
# Epoch 25300: Total Loss = 1.7339e-03, PDE Loss = 5.8813e-04, BC Loss = 1.1458e-03
# Epoch 25400: Total Loss = 2.7391e-03, PDE Loss = 2.5852e-04, BC Loss = 2.4806e-03
# Epoch 25500: Total Loss = 2.0385e-03, PDE Loss = 5.3739e-04, BC Loss = 1.5011e-03
# Epoch 25600: Total Loss = 3.7536e-03, PDE Loss = 5.1310e-04, BC Loss = 3.2405e-03
# Epoch 25700: Total Loss = 3.8045e-03, PDE Loss = 7.4786e-04, BC Loss = 3.0567e-03
# Epoch 25800: Total Loss = 1.8828e-03, PDE Loss = 1.6942e-04, BC Loss = 1.7134e-03
# Epoch 25900: Total Loss = 2.7119e-03, PDE Loss = 1.9323e-04, BC Loss = 2.5186e-03
# Epoch 26000: Total Loss = 1.6779e-03, PDE Loss = 4.8166e-04, BC Loss = 1.1963e-03
# Epoch 26100: Total Loss = 2.8702e-03, PDE Loss = 1.8776e-04, BC Loss = 2.6824e-03
# Epoch 26200: Total Loss = 1.4778e-03, PDE Loss = 1.9384e-04, BC Loss = 1.2839e-03
# Epoch 26300: Total Loss = 3.6461e-03, PDE Loss = 4.3204e-04, BC Loss = 3.2141e-03
# Epoch 26400: Total Loss = 3.4467e-03, PDE Loss = 5.4599e-04, BC Loss = 2.9007e-03
# Epoch 26500: Total Loss = 2.1919e-03, PDE Loss = 1.7260e-04, BC Loss = 2.0193e-03
# Epoch 26600: Total Loss = 2.6396e-03, PDE Loss = 6.3669e-04, BC Loss = 2.0029e-03
# Epoch 26700: Total Loss = 2.0049e-03, PDE Loss = 2.4241e-04, BC Loss = 1.7624e-03
# Epoch 26800: Total Loss = 2.1294e-03, PDE Loss = 4.1234e-04, BC Loss = 1.7171e-03
# Epoch 26900: Total Loss = 1.8438e-03, PDE Loss = 1.5411e-04, BC Loss = 1.6897e-03
# Epoch 27000: Total Loss = 2.4563e-03, PDE Loss = 2.0546e-04, BC Loss = 2.2509e-03
# Epoch 27100: Total Loss = 1.8398e-03, PDE Loss = 1.4565e-04, BC Loss = 1.6941e-03
# Epoch 27200: Total Loss = 1.8025e-03, PDE Loss = 1.6085e-04, BC Loss = 1.6416e-03
# Epoch 27300: Total Loss = 2.0941e-03, PDE Loss = 3.2764e-04, BC Loss = 1.7664e-03
# Epoch 27400: Total Loss = 1.9790e-03, PDE Loss = 2.5216e-04, BC Loss = 1.7269e-03
# Epoch 27500: Total Loss = 1.9153e-03, PDE Loss = 2.1975e-04, BC Loss = 1.6955e-03
# Epoch 27600: Total Loss = 2.1183e-03, PDE Loss = 2.7780e-04, BC Loss = 1.8405e-03
# Epoch 27700: Total Loss = 1.8868e-03, PDE Loss = 3.2143e-04, BC Loss = 1.5654e-03
# Epoch 27800: Total Loss = 1.7464e-03, PDE Loss = 1.6502e-04, BC Loss = 1.5814e-03
# Epoch 27900: Total Loss = 2.1889e-03, PDE Loss = 1.6152e-04, BC Loss = 2.0274e-03
# Epoch 28000: Total Loss = 2.1875e-03, PDE Loss = 1.9658e-04, BC Loss = 1.9909e-03
# Epoch 28100: Total Loss = 1.7352e-03, PDE Loss = 2.8270e-04, BC Loss = 1.4525e-03
# Epoch 28200: Total Loss = 1.6788e-03, PDE Loss = 2.0668e-04, BC Loss = 1.4722e-03
# Epoch 28300: Total Loss = 1.7168e-03, PDE Loss = 1.8401e-04, BC Loss = 1.5328e-03
# Epoch 28400: Total Loss = 2.8124e-03, PDE Loss = 2.4337e-04, BC Loss = 2.5690e-03
# Epoch 28500: Total Loss = 1.9127e-03, PDE Loss = 2.5080e-04, BC Loss = 1.6619e-03
# Epoch 28600: Total Loss = 1.7882e-03, PDE Loss = 1.4202e-04, BC Loss = 1.6462e-03
# Epoch 28700: Total Loss = 1.8263e-03, PDE Loss = 2.2454e-04, BC Loss = 1.6018e-03
# Epoch 28800: Total Loss = 2.8880e-03, PDE Loss = 3.2361e-04, BC Loss = 2.5644e-03
# Epoch 28900: Total Loss = 3.0409e-03, PDE Loss = 4.9480e-04, BC Loss = 2.5461e-03
# Epoch 29000: Total Loss = 1.5882e-03, PDE Loss = 1.2940e-04, BC Loss = 1.4588e-03
# Epoch 29100: Total Loss = 2.0649e-03, PDE Loss = 2.3548e-04, BC Loss = 1.8294e-03
# Epoch 29200: Total Loss = 1.7597e-03, PDE Loss = 3.8749e-04, BC Loss = 1.3722e-03
# Epoch 29300: Total Loss = 1.7314e-03, PDE Loss = 1.8429e-04, BC Loss = 1.5471e-03
# Epoch 29400: Total Loss = 2.5600e-03, PDE Loss = 4.1116e-04, BC Loss = 2.1489e-03
# Epoch 29500: Total Loss = 1.6250e-03, PDE Loss = 1.7022e-04, BC Loss = 1.4548e-03
# Epoch 29600: Total Loss = 2.4361e-03, PDE Loss = 3.3285e-04, BC Loss = 2.1033e-03
# Epoch 29700: Total Loss = 1.6863e-03, PDE Loss = 1.8497e-04, BC Loss = 1.5013e-03
# Epoch 29800: Total Loss = 1.6428e-03, PDE Loss = 2.2175e-04, BC Loss = 1.4211e-03
# Epoch 29900: Total Loss = 2.6652e-03, PDE Loss = 6.9979e-04, BC Loss = 1.9654e-03
# Epoch 30000: Total Loss = 2.5796e-03, PDE Loss = 2.2531e-04, BC Loss = 2.3543e-03
# Epoch 30100: Total Loss = 2.2182e-03, PDE Loss = 1.8820e-04, BC Loss = 2.0300e-03
# Epoch 30200: Total Loss = 2.9299e-03, PDE Loss = 3.6052e-04, BC Loss = 2.5694e-03
# Epoch 30300: Total Loss = 2.3983e-03, PDE Loss = 3.7578e-04, BC Loss = 2.0225e-03
# Epoch 30400: Total Loss = 1.6975e-03, PDE Loss = 2.3614e-04, BC Loss = 1.4614e-03
# Epoch 30500: Total Loss = 3.6364e-03, PDE Loss = 3.3650e-04, BC Loss = 3.2999e-03
# Epoch 30600: Total Loss = 3.0659e-03, PDE Loss = 2.3465e-04, BC Loss = 2.8313e-03
# Epoch 30700: Total Loss = 2.9183e-03, PDE Loss = 2.8398e-04, BC Loss = 2.6343e-03
# Epoch 30800: Total Loss = 2.7538e-03, PDE Loss = 6.0564e-04, BC Loss = 2.1482e-03
# Epoch 30900: Total Loss = 2.1815e-03, PDE Loss = 2.6029e-04, BC Loss = 1.9212e-03
# Epoch 31000: Total Loss = 2.0035e-03, PDE Loss = 2.3282e-04, BC Loss = 1.7706e-03
# Epoch 31100: Total Loss = 1.8828e-03, PDE Loss = 2.1056e-04, BC Loss = 1.6722e-03
# Epoch 31200: Total Loss = 1.8110e-03, PDE Loss = 1.8310e-04, BC Loss = 1.6279e-03
# Epoch 31300: Total Loss = 1.6732e-03, PDE Loss = 2.0999e-04, BC Loss = 1.4632e-03
# Epoch 31400: Total Loss = 1.6107e-03, PDE Loss = 2.0949e-04, BC Loss = 1.4012e-03
# Epoch 31500: Total Loss = 1.5534e-03, PDE Loss = 1.2777e-04, BC Loss = 1.4256e-03
# Epoch 31600: Total Loss = 1.7782e-03, PDE Loss = 3.6152e-04, BC Loss = 1.4167e-03
# Epoch 31700: Total Loss = 1.7355e-03, PDE Loss = 2.7496e-04, BC Loss = 1.4606e-03
# Epoch 31800: Total Loss = 9.8309e-03, PDE Loss = 2.2386e-03, BC Loss = 7.5923e-03
# Epoch 31900: Total Loss = 3.2652e-03, PDE Loss = 2.5358e-04, BC Loss = 3.0116e-03
# Epoch 32000: Total Loss = 3.1225e-03, PDE Loss = 2.1801e-04, BC Loss = 2.9045e-03
# Epoch 32100: Total Loss = 2.7558e-03, PDE Loss = 2.8841e-04, BC Loss = 2.4674e-03
# Epoch 32200: Total Loss = 2.4529e-03, PDE Loss = 2.6132e-04, BC Loss = 2.1915e-03
# Epoch 32300: Total Loss = 2.6494e-03, PDE Loss = 2.6883e-04, BC Loss = 2.3805e-03
# Epoch 32400: Total Loss = 2.1856e-03, PDE Loss = 2.8639e-04, BC Loss = 1.8992e-03
# Epoch 32500: Total Loss = 2.1196e-03, PDE Loss = 2.3498e-04, BC Loss = 1.8846e-03
# Epoch 32600: Total Loss = 2.2747e-03, PDE Loss = 2.4006e-04, BC Loss = 2.0346e-03
# Epoch 32700: Total Loss = 1.9918e-03, PDE Loss = 2.3496e-04, BC Loss = 1.7569e-03
# Epoch 32800: Total Loss = 1.9686e-03, PDE Loss = 2.0353e-04, BC Loss = 1.7651e-03
# Epoch 32900: Total Loss = 2.0061e-03, PDE Loss = 2.2994e-04, BC Loss = 1.7761e-03
# Epoch 33000: Total Loss = 1.8853e-03, PDE Loss = 2.1176e-04, BC Loss = 1.6736e-03
# Epoch 33100: Total Loss = 2.1490e-03, PDE Loss = 5.3680e-04, BC Loss = 1.6122e-03
# Epoch 33200: Total Loss = 2.1412e-03, PDE Loss = 3.8785e-04, BC Loss = 1.7534e-03
# Epoch 33300: Total Loss = 1.8267e-03, PDE Loss = 2.8606e-04, BC Loss = 1.5406e-03
# Epoch 33400: Total Loss = 4.3927e-03, PDE Loss = 9.8947e-04, BC Loss = 3.4033e-03
# Epoch 33500: Total Loss = 1.5310e-03, PDE Loss = 1.6179e-04, BC Loss = 1.3692e-03
# Epoch 33600: Total Loss = 1.5672e-03, PDE Loss = 1.6538e-04, BC Loss = 1.4018e-03
# Epoch 33700: Total Loss = 2.4965e-03, PDE Loss = 4.6128e-04, BC Loss = 2.0353e-03
# Epoch 33800: Total Loss = 2.1057e-03, PDE Loss = 1.7879e-04, BC Loss = 1.9269e-03
# Epoch 33900: Total Loss = 2.0423e-03, PDE Loss = 3.0331e-04, BC Loss = 1.7389e-03
# Epoch 34000: Total Loss = 2.0436e-03, PDE Loss = 2.0338e-04, BC Loss = 1.8402e-03
# Epoch 34100: Total Loss = 2.1178e-03, PDE Loss = 3.0853e-04, BC Loss = 1.8093e-03
# Epoch 34200: Total Loss = 2.2574e-03, PDE Loss = 3.5046e-04, BC Loss = 1.9069e-03
# Epoch 34300: Total Loss = 2.0964e-03, PDE Loss = 3.7002e-04, BC Loss = 1.7264e-03
# Epoch 34400: Total Loss = 1.9238e-03, PDE Loss = 2.0723e-04, BC Loss = 1.7165e-03
# Epoch 34500: Total Loss = 1.6825e-03, PDE Loss = 2.8704e-04, BC Loss = 1.3954e-03
# Epoch 34600: Total Loss = 1.8684e-03, PDE Loss = 2.0756e-04, BC Loss = 1.6608e-03
# Epoch 34700: Total Loss = 2.0044e-03, PDE Loss = 3.9060e-04, BC Loss = 1.6138e-03
# Epoch 34800: Total Loss = 2.5575e-03, PDE Loss = 7.8467e-04, BC Loss = 1.7728e-03
# Epoch 34900: Total Loss = 2.4071e-03, PDE Loss = 4.8753e-04, BC Loss = 1.9196e-03
# Epoch 35000: Total Loss = 1.7652e-03, PDE Loss = 4.1848e-04, BC Loss = 1.3467e-03
# Epoch 35100: Total Loss = 1.8123e-03, PDE Loss = 3.7374e-04, BC Loss = 1.4386e-03
# Epoch 35200: Total Loss = 1.5388e-03, PDE Loss = 2.0367e-04, BC Loss = 1.3351e-03
# Epoch 35300: Total Loss = 1.5905e-03, PDE Loss = 2.2557e-04, BC Loss = 1.3649e-03
# Epoch 35400: Total Loss = 1.7809e-03, PDE Loss = 1.9501e-04, BC Loss = 1.5859e-03
# Epoch 35500: Total Loss = 1.4970e-03, PDE Loss = 1.5262e-04, BC Loss = 1.3444e-03
# Epoch 35600: Total Loss = 1.8414e-03, PDE Loss = 4.4093e-04, BC Loss = 1.4005e-03
# Epoch 35700: Total Loss = 2.9503e-03, PDE Loss = 3.2353e-04, BC Loss = 2.6268e-03
# Epoch 35800: Total Loss = 1.7760e-03, PDE Loss = 1.4652e-04, BC Loss = 1.6295e-03
# Epoch 35900: Total Loss = 1.8099e-03, PDE Loss = 1.9053e-04, BC Loss = 1.6194e-03
# Epoch 36000: Total Loss = 2.7341e-03, PDE Loss = 2.8313e-04, BC Loss = 2.4510e-03
# Epoch 36100: Total Loss = 1.7806e-03, PDE Loss = 2.1595e-04, BC Loss = 1.5646e-03
# Epoch 36200: Total Loss = 1.9311e-03, PDE Loss = 2.9836e-04, BC Loss = 1.6327e-03
# Epoch 36300: Total Loss = 4.0554e-03, PDE Loss = 5.7234e-04, BC Loss = 3.4830e-03
# Epoch 36400: Total Loss = 1.6344e-03, PDE Loss = 2.5585e-04, BC Loss = 1.3785e-03
# Epoch 36500: Total Loss = 2.9490e-03, PDE Loss = 2.6544e-04, BC Loss = 2.6836e-03
# Epoch 36600: Total Loss = 1.6764e-03, PDE Loss = 2.5004e-04, BC Loss = 1.4263e-03
# Epoch 36700: Total Loss = 1.5117e-03, PDE Loss = 2.4063e-04, BC Loss = 1.2710e-03
# Epoch 36800: Total Loss = 1.6186e-03, PDE Loss = 1.5652e-04, BC Loss = 1.4621e-03
# Epoch 36900: Total Loss = 1.8054e-03, PDE Loss = 2.4531e-04, BC Loss = 1.5601e-03
# Epoch 37000: Total Loss = 2.1159e-03, PDE Loss = 2.8484e-04, BC Loss = 1.8311e-03
# Epoch 37100: Total Loss = 1.9121e-03, PDE Loss = 5.7372e-04, BC Loss = 1.3384e-03
# Epoch 37200: Total Loss = 2.9166e-03, PDE Loss = 2.2824e-04, BC Loss = 2.6883e-03
# Epoch 37300: Total Loss = 2.7551e-03, PDE Loss = 4.0526e-04, BC Loss = 2.3498e-03
# Epoch 37400: Total Loss = 1.5270e-03, PDE Loss = 1.8197e-04, BC Loss = 1.3451e-03
# Epoch 37500: Total Loss = 1.3693e-03, PDE Loss = 1.3750e-04, BC Loss = 1.2318e-03
# Epoch 37600: Total Loss = 2.4896e-03, PDE Loss = 2.8333e-04, BC Loss = 2.2063e-03
# Epoch 37700: Total Loss = 1.7569e-03, PDE Loss = 2.2145e-04, BC Loss = 1.5355e-03
# Epoch 37800: Total Loss = 1.5188e-03, PDE Loss = 1.8588e-04, BC Loss = 1.3329e-03
# Epoch 37900: Total Loss = 2.3280e-03, PDE Loss = 3.1458e-04, BC Loss = 2.0134e-03
# Epoch 38000: Total Loss = 1.3975e-03, PDE Loss = 1.4629e-04, BC Loss = 1.2512e-03
# Epoch 38100: Total Loss = 2.7559e-03, PDE Loss = 4.7417e-04, BC Loss = 2.2817e-03
# Epoch 38200: Total Loss = 1.4851e-03, PDE Loss = 1.8759e-04, BC Loss = 1.2975e-03
# Epoch 38300: Total Loss = 1.9634e-03, PDE Loss = 2.0955e-04, BC Loss = 1.7539e-03
# Epoch 38400: Total Loss = 1.9770e-03, PDE Loss = 4.2692e-04, BC Loss = 1.5500e-03
# Epoch 38500: Total Loss = 1.4665e-03, PDE Loss = 2.3013e-04, BC Loss = 1.2364e-03
# Epoch 38600: Total Loss = 1.5287e-03, PDE Loss = 1.6149e-04, BC Loss = 1.3673e-03
# Epoch 38700: Total Loss = 1.3715e-03, PDE Loss = 1.4578e-04, BC Loss = 1.2257e-03
# Epoch 38800: Total Loss = 2.2034e-03, PDE Loss = 3.1284e-04, BC Loss = 1.8906e-03
# Epoch 38900: Total Loss = 1.8460e-03, PDE Loss = 3.2675e-04, BC Loss = 1.5193e-03
# Epoch 39000: Total Loss = 1.9880e-03, PDE Loss = 3.6662e-04, BC Loss = 1.6214e-03
# Epoch 39100: Total Loss = 1.5973e-03, PDE Loss = 2.9341e-04, BC Loss = 1.3039e-03
# Epoch 39200: Total Loss = 2.0094e-03, PDE Loss = 2.5345e-04, BC Loss = 1.7559e-03
# Epoch 39300: Total Loss = 2.2257e-03, PDE Loss = 2.6086e-04, BC Loss = 1.9649e-03
# Epoch 39400: Total Loss = 1.9390e-03, PDE Loss = 2.9496e-04, BC Loss = 1.6440e-03
# Epoch 39500: Total Loss = 2.2182e-03, PDE Loss = 4.5062e-04, BC Loss = 1.7676e-03
# Epoch 39600: Total Loss = 1.3702e-03, PDE Loss = 1.5196e-04, BC Loss = 1.2182e-03
# Epoch 39700: Total Loss = 2.5237e-03, PDE Loss = 2.2714e-04, BC Loss = 2.2966e-03
# Epoch 39800: Total Loss = 2.7730e-03, PDE Loss = 7.4729e-04, BC Loss = 2.0258e-03
# Epoch 39900: Total Loss = 1.3272e-03, PDE Loss = 1.4057e-04, BC Loss = 1.1867e-03
# Epoch 40000: Total Loss = 1.4878e-03, PDE Loss = 2.5113e-04, BC Loss = 1.2367e-03
# Epoch 40100: Total Loss = 2.1250e-03, PDE Loss = 1.8013e-04, BC Loss = 1.9449e-03
# Epoch 40200: Total Loss = 1.5200e-03, PDE Loss = 2.1455e-04, BC Loss = 1.3054e-03
# Epoch 40300: Total Loss = 1.5339e-03, PDE Loss = 2.5753e-04, BC Loss = 1.2764e-03
# Epoch 40400: Total Loss = 1.3534e-03, PDE Loss = 1.5120e-04, BC Loss = 1.2022e-03
# Epoch 40500: Total Loss = 1.8719e-03, PDE Loss = 4.0855e-04, BC Loss = 1.4634e-03
# Epoch 40600: Total Loss = 1.4196e-03, PDE Loss = 1.5009e-04, BC Loss = 1.2695e-03
# Epoch 40700: Total Loss = 1.3277e-03, PDE Loss = 1.4672e-04, BC Loss = 1.1810e-03
# Epoch 40800: Total Loss = 2.7414e-03, PDE Loss = 2.4899e-04, BC Loss = 2.4924e-03
# Epoch 40900: Total Loss = 1.6817e-03, PDE Loss = 2.2500e-04, BC Loss = 1.4567e-03
# Epoch 41000: Total Loss = 3.6124e-03, PDE Loss = 1.3890e-03, BC Loss = 2.2234e-03
# Epoch 41100: Total Loss = 1.3092e-03, PDE Loss = 1.3248e-04, BC Loss = 1.1767e-03
# Epoch 41200: Total Loss = 1.4913e-03, PDE Loss = 2.3420e-04, BC Loss = 1.2571e-03
# Epoch 41300: Total Loss = 1.3971e-03, PDE Loss = 1.8455e-04, BC Loss = 1.2126e-03
# Epoch 41400: Total Loss = 1.9630e-03, PDE Loss = 2.1905e-04, BC Loss = 1.7439e-03
# Epoch 41500: Total Loss = 1.6533e-03, PDE Loss = 2.0970e-04, BC Loss = 1.4436e-03
# Epoch 41600: Total Loss = 1.5968e-03, PDE Loss = 3.2132e-04, BC Loss = 1.2754e-03
# Epoch 41700: Total Loss = 1.4877e-03, PDE Loss = 2.0672e-04, BC Loss = 1.2810e-03
# Epoch 41800: Total Loss = 1.7029e-03, PDE Loss = 2.6023e-04, BC Loss = 1.4426e-03
# Epoch 41900: Total Loss = 1.3077e-03, PDE Loss = 1.3362e-04, BC Loss = 1.1741e-03
# Epoch 42000: Total Loss = 5.0041e-03, PDE Loss = 6.0578e-04, BC Loss = 4.3983e-03
# Epoch 42100: Total Loss = 1.7231e-03, PDE Loss = 1.6825e-04, BC Loss = 1.5548e-03
# Epoch 42200: Total Loss = 1.7898e-03, PDE Loss = 2.8148e-04, BC Loss = 1.5083e-03
# Epoch 42300: Total Loss = 1.4711e-03, PDE Loss = 2.2287e-04, BC Loss = 1.2483e-03
# Epoch 42400: Total Loss = 3.5820e-03, PDE Loss = 3.6722e-04, BC Loss = 3.2148e-03
# Epoch 42500: Total Loss = 2.7344e-03, PDE Loss = 2.4816e-04, BC Loss = 2.4862e-03
# Epoch 42600: Total Loss = 2.0515e-03, PDE Loss = 2.3732e-04, BC Loss = 1.8142e-03
# Epoch 42700: Total Loss = 1.8737e-03, PDE Loss = 3.5325e-04, BC Loss = 1.5204e-03
# Epoch 42800: Total Loss = 1.5852e-03, PDE Loss = 1.9257e-04, BC Loss = 1.3926e-03
# Epoch 42900: Total Loss = 1.4434e-03, PDE Loss = 2.6503e-04, BC Loss = 1.1784e-03
# Epoch 43000: Total Loss = 1.4186e-03, PDE Loss = 2.0732e-04, BC Loss = 1.2112e-03
# Epoch 43100: Total Loss = 1.4087e-03, PDE Loss = 1.4629e-04, BC Loss = 1.2625e-03
# Epoch 43200: Total Loss = 1.7106e-03, PDE Loss = 2.2480e-04, BC Loss = 1.4858e-03
# Epoch 43300: Total Loss = 1.5335e-03, PDE Loss = 2.0742e-04, BC Loss = 1.3261e-03
# Epoch 43400: Total Loss = 1.3694e-03, PDE Loss = 1.7362e-04, BC Loss = 1.1958e-03
# Epoch 43500: Total Loss = 1.6002e-03, PDE Loss = 3.3446e-04, BC Loss = 1.2657e-03
# Epoch 43600: Total Loss = 1.4467e-03, PDE Loss = 3.1090e-04, BC Loss = 1.1358e-03
# Epoch 43700: Total Loss = 1.3367e-03, PDE Loss = 1.5991e-04, BC Loss = 1.1768e-03
# Epoch 43800: Total Loss = 1.7875e-03, PDE Loss = 4.8037e-04, BC Loss = 1.3071e-03
# Epoch 43900: Total Loss = 1.3220e-03, PDE Loss = 1.4919e-04, BC Loss = 1.1728e-03
# Epoch 44000: Total Loss = 1.8498e-03, PDE Loss = 1.7151e-04, BC Loss = 1.6783e-03
# Epoch 44100: Total Loss = 1.4311e-03, PDE Loss = 1.7523e-04, BC Loss = 1.2559e-03
# Epoch 44200: Total Loss = 1.0141e-02, PDE Loss = 2.7908e-03, BC Loss = 7.3501e-03
# Epoch 44300: Total Loss = 5.7053e-03, PDE Loss = 1.0312e-03, BC Loss = 4.6742e-03
# Epoch 44400: Total Loss = 3.9273e-03, PDE Loss = 4.1796e-04, BC Loss = 3.5093e-03
# Epoch 44500: Total Loss = 3.5282e-03, PDE Loss = 3.7388e-04, BC Loss = 3.1544e-03
# Epoch 44600: Total Loss = 3.4816e-03, PDE Loss = 5.0555e-04, BC Loss = 2.9761e-03
# Epoch 44700: Total Loss = 3.2580e-03, PDE Loss = 3.6119e-04, BC Loss = 2.8968e-03
# Epoch 44800: Total Loss = 3.1854e-03, PDE Loss = 3.6950e-04, BC Loss = 2.8159e-03
# Epoch 44900: Total Loss = 4.1980e-03, PDE Loss = 5.5188e-04, BC Loss = 3.6462e-03
# Epoch 45000: Total Loss = 3.3567e-03, PDE Loss = 3.8369e-04, BC Loss = 2.9730e-03
# Epoch 45100: Total Loss = 3.0168e-03, PDE Loss = 3.5805e-04, BC Loss = 2.6588e-03
# Epoch 45200: Total Loss = 3.0190e-03, PDE Loss = 3.6024e-04, BC Loss = 2.6587e-03
# Epoch 45300: Total Loss = 2.9022e-03, PDE Loss = 3.4718e-04, BC Loss = 2.5550e-03
# Epoch 45400: Total Loss = 2.7758e-03, PDE Loss = 3.5689e-04, BC Loss = 2.4189e-03
# Epoch 45500: Total Loss = 2.6932e-03, PDE Loss = 3.2753e-04, BC Loss = 2.3657e-03
# Epoch 45600: Total Loss = 2.6180e-03, PDE Loss = 3.9790e-04, BC Loss = 2.2201e-03
# Epoch 45700: Total Loss = 2.4504e-03, PDE Loss = 2.7643e-04, BC Loss = 2.1739e-03
# Epoch 45800: Total Loss = 2.8380e-03, PDE Loss = 3.5118e-04, BC Loss = 2.4868e-03
# Epoch 45900: Total Loss = 2.2135e-03, PDE Loss = 2.4112e-04, BC Loss = 1.9724e-03
# Epoch 46000: Total Loss = 2.1218e-03, PDE Loss = 2.6085e-04, BC Loss = 1.8610e-03
# Epoch 46100: Total Loss = 2.0460e-03, PDE Loss = 2.5096e-04, BC Loss = 1.7950e-03
# Epoch 46200: Total Loss = 1.9940e-03, PDE Loss = 2.3740e-04, BC Loss = 1.7566e-03
# Epoch 46300: Total Loss = 2.0511e-03, PDE Loss = 4.2880e-04, BC Loss = 1.6223e-03
# Epoch 46400: Total Loss = 2.0362e-03, PDE Loss = 3.3832e-04, BC Loss = 1.6979e-03
# Epoch 46500: Total Loss = 2.1032e-03, PDE Loss = 2.9044e-04, BC Loss = 1.8128e-03
# Epoch 46600: Total Loss = 2.0835e-03, PDE Loss = 2.9664e-04, BC Loss = 1.7868e-03
# Epoch 46700: Total Loss = 2.2125e-03, PDE Loss = 2.6009e-04, BC Loss = 1.9524e-03
# Epoch 46800: Total Loss = 1.8504e-03, PDE Loss = 2.5106e-04, BC Loss = 1.5994e-03
# Epoch 46900: Total Loss = 1.7866e-03, PDE Loss = 3.3509e-04, BC Loss = 1.4515e-03
# Epoch 47000: Total Loss = 1.6992e-03, PDE Loss = 2.3585e-04, BC Loss = 1.4634e-03
# Epoch 47100: Total Loss = 1.9373e-03, PDE Loss = 4.3752e-04, BC Loss = 1.4998e-03
# Epoch 47200: Total Loss = 2.4058e-03, PDE Loss = 7.0788e-04, BC Loss = 1.6979e-03
# Epoch 47300: Total Loss = 1.7076e-03, PDE Loss = 1.9753e-04, BC Loss = 1.5101e-03
# Epoch 47400: Total Loss = 1.6591e-03, PDE Loss = 3.1744e-04, BC Loss = 1.3417e-03
# Epoch 47500: Total Loss = 1.6614e-03, PDE Loss = 3.5878e-04, BC Loss = 1.3026e-03
# Epoch 47600: Total Loss = 1.8981e-03, PDE Loss = 2.3222e-04, BC Loss = 1.6659e-03
# Epoch 47700: Total Loss = 2.0776e-03, PDE Loss = 2.3151e-04, BC Loss = 1.8461e-03
# Epoch 47800: Total Loss = 1.5152e-03, PDE Loss = 1.9083e-04, BC Loss = 1.3243e-03
# Epoch 47900: Total Loss = 1.5690e-03, PDE Loss = 2.2011e-04, BC Loss = 1.3489e-03
# Epoch 48000: Total Loss = 1.5861e-03, PDE Loss = 2.5558e-04, BC Loss = 1.3305e-03
# Epoch 48100: Total Loss = 1.4860e-03, PDE Loss = 1.8161e-04, BC Loss = 1.3044e-03
# Epoch 48200: Total Loss = 1.4809e-03, PDE Loss = 2.0555e-04, BC Loss = 1.2754e-03
# Epoch 48300: Total Loss = 1.5701e-03, PDE Loss = 1.7825e-04, BC Loss = 1.3918e-03
# Epoch 48400: Total Loss = 1.5403e-03, PDE Loss = 2.3999e-04, BC Loss = 1.3003e-03
# Epoch 48500: Total Loss = 1.6828e-03, PDE Loss = 4.1143e-04, BC Loss = 1.2713e-03
# Epoch 48600: Total Loss = 1.6970e-03, PDE Loss = 2.2513e-04, BC Loss = 1.4719e-03
# Epoch 48700: Total Loss = 1.6016e-03, PDE Loss = 1.9279e-04, BC Loss = 1.4088e-03
# Epoch 48800: Total Loss = 1.4597e-03, PDE Loss = 2.5973e-04, BC Loss = 1.2000e-03
# Epoch 48900: Total Loss = 1.4328e-03, PDE Loss = 1.6691e-04, BC Loss = 1.2659e-03
# Epoch 49000: Total Loss = 1.7429e-03, PDE Loss = 2.4792e-04, BC Loss = 1.4950e-03
# Epoch 49100: Total Loss = 1.8881e-03, PDE Loss = 3.3580e-04, BC Loss = 1.5523e-03
# Epoch 49200: Total Loss = 1.4906e-03, PDE Loss = 1.8042e-04, BC Loss = 1.3101e-03
# Epoch 49300: Total Loss = 1.4187e-03, PDE Loss = 1.5237e-04, BC Loss = 1.2663e-03
# Epoch 49400: Total Loss = 1.4253e-03, PDE Loss = 1.5961e-04, BC Loss = 1.2657e-03
# Epoch 49500: Total Loss = 2.9505e-03, PDE Loss = 2.7418e-04, BC Loss = 2.6763e-03
# Epoch 49600: Total Loss = 1.6178e-03, PDE Loss = 1.9033e-04, BC Loss = 1.4275e-03
# Epoch 49700: Total Loss = 2.1112e-03, PDE Loss = 1.9715e-04, BC Loss = 1.9140e-03
# Epoch 49800: Total Loss = 1.3916e-03, PDE Loss = 1.5767e-04, BC Loss = 1.2339e-03
# Epoch 49900: Total Loss = 1.4791e-03, PDE Loss = 1.7219e-04, BC Loss = 1.3069e-03
# Reached maximum epochs (50000) with final loss 1.6029e-03

# %%
pinn.plot_training_points()

# %%
pinn.save_contour_plot('velocity_contour_1000.png', 1000,  300) 
pinn.plot_velocity_contour()

# %%
pinn.find_vortex_center('left', 0.2,  200)
# Out:
# Left wall vortex center approx at: x = 0.0000, y = 0.0020
# array([0.        , 0.00201005], dtype=float32)

# %%
pinn.find_vortex_center('right', 0.2,  200)
# Out:
# Right wall vortex center approx at: x = 0.9990, y = 0.0030
# array([0.998995  , 0.00301508], dtype=float32)

# %%
pinn.plot_comparison_figure( ghia_data_1000,50,  100,"camp_1000.png")
# Out:
# Figure saved to camp_1000.png

# %%
# After training
pinn.plot_loss_history(True, (12, 6),"loss_1000.png")# Shows loss vs epochs on log scale


# To get the raw data
loss_data = pinn.get_loss_history()
# Out:
# Figure saved to loss_1000.png

# %%
pinn.save_contour_plot('velocity_contour_1000.png', 1000,  300)

# %%
ghia_data_100 = {
    'u_vertical': (
        np.array([0.0000, 0.0547, 0.0625, 0.0703, 0.1016, 0.1719, 0.2813, 0.4531, 0.5000, 0.6172, 0.7344, 0.8516, 0.9531, 0.9609, 0.9688, 0.9766, 1.0000]),  # y positions
        np.array([0.00000, -0.03717, -0.04192, -0.04775, -0.06434, -0.10150, -0.15662, -0.21090, 0.20581, -0.13641, 0.00332, 0.23151, 0.68717, 0.73722, 0.78871, 0.84123, 1.00000])  # u velocities
    ),
    'v_horizontal': (
        np.array([0.0000, 0.0625, 0.0703, 0.0781, 0.0938, 0.1563, 0.2266, 0.2344, 0.5000, 0.8047, 0.8594, 0.9063, 0.9453, 0.9531, 0.9609, 0.9688, 1.0000]),  # x positions
        np.array([0.00000, 0.09233, 0.10091, 0.10890, 0.12317, 0.16077, 0.17507, 0.17527, 0.05454, -0.24533, -0.22445, -0.16914, -0.10313, -0.08864, -0.07391, -0.05906, 0.00000])  # v velocities
    )
}

ghia_data_400 = {
    'u_vertical': (
        np.array([0.0000, 0.0547, 0.0625, 0.0703, 0.1016, 0.1719, 0.2813, 0.4531, 0.5000, 0.6172, 0.7344, 0.8516, 0.9531, 0.9609, 0.9688, 0.9766, 1.0000]),  # y positions
        np.array([0.00000, -0.08186, -0.09266, -0.10338, -0.14612, -0.24299, -0.32726, -0.17119, -0.11477, 0.02135, 0.16256, 0.29093, 0.55892, 0.61756, 0.68439, 0.75837, 1.00000])  # u velocities
    ),
    'v_horizontal': (
        np.array([0.0000, 0.0625, 0.0703, 0.0781, 0.0938, 0.1563, 0.2266, 0.2344, 0.5000, 0.8047, 0.8594, 0.9063, 0.9453, 0.9531, 0.9609, 0.9688, 1.0000]),  # x positions
        np.array([0.00000, 0.18360, 0.19713, 0.20920, 0.22965, 0.28124, 0.30203, 0.30174, 0.05186, -0.38598, -0.44993, -0.23827, -0.22847, -0.19254, -0.15663, -0.12146, 0.00000])  # v velocities
    )
}

ghia_data_1000 = {
    'u_vertical': (
        np.array([0.0000, 0.0547, 0.0625, 0.0703, 0.1016, 0.1719, 0.2813, 0.4531, 0.5000, 0.6172, 0.7344, 0.8516, 0.9531, 0.9609, 0.9688, 0.9766, 1.0000]),  # y positions
        np.array([0.00000, -0.18109, -0.20196, -0.22220, -0.29730, -0.38289, -0.27805, 0.10648, 0.31683, 0.38857, 0.30070, 0.10890, -0.05702, -0.07404, -0.08823, -0.09947, 0.00000])  # u velocities
    ),
    'v_horizontal': (
        np.array([0.0000, 0.0625, 0.0703, 0.0781, 0.0938, 0.1563, 0.2266, 0.2344, 0.5000, 0.8047, 0.8594, 0.9063, 0.9453, 0.9531, 0.9609, 0.9688, 1.0000]),  # x positions
        np.array([0.00000, 0.27485, 0.29012, 0.30353, 0.32627, 0.37095, 0.33075, 0.32235, 0.02526, -0.31966, -0.42665, -0.51550, -0.39188, -0.33714, -0.27669, -0.21388, 0.00000])  # v velocities
    )
}
